# %%
import pandas as pd

# %%
# import the data
data = pd.read_csv("data/german_data_clean.csv")

# %%
data.head()
# Out:
#        checking_account  duration_months  \
# 0         ... <  0 euro                6
# 1  0 <= ... <  102 euro               48
# 2   No checking account               12
# 3         ... <  0 euro               42
# 4         ... <  0 euro               24
#
#                                       credit_history              purpose  \
# 0  critical account/other credits existing (not a...     radio/television
# 1           existing credits paid back duly till now     radio/television
# 2  critical account/other credits existing (not a...            education
# 3           existing credits paid back duly till now  furniture/equipment
# 4                    delay in paying off in the past            car (new)
#
#    credit_amount                      savings present_employment_since  \
# 0           1169  unknown/ no savings account            .. >= 7 years
# 1           5951               ... <  51 euro      1  <= ... < 4 years
# ...

# %%
# technische beschrijving
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   checking_account           1000 non-null   object
#  1   duration_months            1000 non-null   int64
#  2   credit_history             1000 non-null   object
#  3   purpose                    1000 non-null   object
#  4   credit_amount              1000 non-null   int64
#  5   savings                    1000 non-null   object
#  6   present_employment_since   1000 non-null   object
#  7   installment_rate           1000 non-null   int64
#  8   personal_status_sex        1000 non-null   object
#  9   other_deptors              1000 non-null   object
#  10  present_residence          1000 non-null   int64
#  11  property                   1000 non-null   object
#  12  age_years                  1000 non-null   int64
# ...

# %%
# inhoudelijke samenvatting
data.describe()
# Out:
#        duration_months  credit_amount  installment_rate  present_residence  \
# count      1000.000000    1000.000000       1000.000000        1000.000000
# mean         20.903000    3271.258000          2.973000           2.845000
# std          12.058814    2822.736876          1.118715           1.103718
# min           4.000000     250.000000          1.000000           1.000000
# 25%          12.000000    1365.500000          2.000000           2.000000
# 50%          18.000000    2319.500000          3.000000           3.000000
# 75%          24.000000    3972.250000          4.000000           4.000000
# max          72.000000   18424.000000          4.000000           4.000000
#
#          age_years  existing_credits  people_liable_maintenance     response
# count  1000.000000       1000.000000                1000.000000  1000.000000
# mean     35.546000          1.407000                   1.155000     0.300000
# ...

# %%
data['age_years'].mean()
# Out:
# np.float64(35.546)

# %%
data.shape
# Out:
# (1000, 21)

# %%
data.columns
# Out:
# Index(['checking_account', 'duration_months', 'credit_history', 'purpose',
#        'credit_amount', 'savings', 'present_employment_since',
#        'installment_rate', 'personal_status_sex', 'other_deptors',
#        'present_residence', 'property', 'age_years', 'other_installment_plans',
#        'housing', 'existing_credits', 'job', 'people_liable_maintenance',
#        'telephone', 'foreign_worker', 'response'],
#       dtype='object')

# %% [markdown]
# ## Selecting rows and columns

# %%
data['credit_amount'].sum()
# Out:
# np.int64(3271258)

# %%
data[['credit_amount', 'duration_months']].mean()
# Out:
# credit_amount      3271.258
# duration_months      20.903
# dtype: float64

# %% [markdown]
# ### `.loc` en `.iloc`
#
# * `loc` --> Zoekt naar de rij **nummner**
# * `iloc` --> Zoekt naar de rij **positie**

# %%
data_sorted = data.sort_values(by="credit_amount", ascending=False)
data_sorted
# Out:
#          checking_account  duration_months  \
# 915  0 <= ... <  102 euro               48
# 95   0 <= ... <  102 euro               54
# 818         ... <  0 euro               36
# 887  0 <= ... <  102 euro               48
# 637   No checking account               60
# ..                    ...              ...
# 458         ... <  0 euro                6
# 157         ... <  0 euro               12
# 177         ... <  0 euro                6
# 309  0 <= ... <  102 euro                9
# 725   No checking account                6
#
#                                         credit_history              purpose  \
# 915       no credits taken/ all credits paid back duly               others
# 95        no credits taken/ all credits paid back duly             business
# 818           existing credits paid back duly till now               others
# 887           existing credits paid back duly till now             business
# ...

# %% [markdown]
# ## Filtering

# %%
# using query
data.query("age_years > 50 & duration_months < 10") 
# data.query("age_years > 50 | duration_months < 10")
# Out:
#          checking_account  duration_months  \
# 0           ... <  0 euro                6
# 4           ... <  0 euro               24
# 6     No checking account               24
# 8     No checking account               12
# 13          ... <  0 euro               24
# ..                    ...              ...
# 964  0 <= ... <  102 euro                6
# 967   No checking account               15
# 975           >= 102 euro               24
# 976  0 <= ... <  102 euro                6
# 987   No checking account               13
#
#                                         credit_history              purpose  \
# 0    critical account/other credits existing (not a...     radio/television
# 4                      delay in paying off in the past            car (new)
# 6             existing credits paid back duly till now  furniture/equipment
# 8             existing credits paid back duly till now     radio/television
# ...

# %% [markdown]
# ## Group by and aggregate

# %%
selected_columns = ['purpose', 'credit_amount', 'age_years']

data[selected_columns].groupby("purpose").agg({
    'credit_amount': 'sum',
    'age_years': 'mean'
})
# Out:
#                      credit_amount  age_years
# purpose
# business                    403330  35.484536
# car (new)                   716748  37.089744
# car (used)                  553133  37.252427
# domestic appliances          17976  34.250000
# education                   159020  38.940000
# furniture/equipment         555125  32.458564
# others                       98512  39.916667
# radio/television            696543  34.700000
# repairs                      60018  38.545455
# retraining                   10853  34.666667
